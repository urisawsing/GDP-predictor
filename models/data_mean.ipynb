# %%
import sqlite3
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_squared_error
import sys
sys.path.append("..")
from utils import config

# %%
def encode(A):
	classes = np.unique(A)
	dictionary = dict(zip(classes, range(len(classes))))
	A_numeric = list(map(dictionary.get, A))
	return(A_numeric, dictionary)

# %%
con = sqlite3.connect(config.DATABASE_PATH) 

query = '''
SELECT c.CountryCode, i.IndicatorCode,ci.Year, ci.Value
FROM CountryIndicators as ci, Countries as c, Indicators as i
WHERE ci.CountryCode=c.CountryCode AND i.IndicatorCode=ci.IndicatorCode  ;
'''

table = pd.read_sql_query(query, con)

con.close()

# %%
print(table.shape)
table.head()
# Out:
# (5026221, 4)
#   CountryCode   IndicatorCode  Year         Value
# 0         ARB     SP.ADO.TFRT  1960  1.335609e+02
# 1         ARB     SP.POP.DPND  1960  8.779760e+01
# 2         ARB  SP.POP.DPND.OL  1960  6.634579e+00
# 3         ARB  SP.POP.DPND.YG  1960  8.102333e+01
# 4         ARB  MS.MIL.XPRT.KD  1960  3.000000e+06

# %%
country_codes = pd.DataFrame(set(table['CountryCode']))

# %%
country_codes
# Out:
#        0
# 0    SRB
# 1    AGO
# 2    ALB
# 3    KIR
# 4    IRL
# ..   ...
# 242  SYR
# 243  VNM
# 244  SLE
# 245  DOM
# 246  ERI
#
# [247 rows x 1 columns]

# %%
country_indicators_table = table.pivot_table(index = ['CountryCode','Year'], columns = "IndicatorCode", values = 'Value')
country_indicators_table['nextyearGDPgrowth'] = country_indicators_table['NY.GDP.MKTP.KD.ZG'].shift(periods = -1)
#test.to_sql("formatted", con, if_exists="replace")

# %%
country_indicators_table
# Out:
# IndicatorCode     SI.SPR.PCAP.ZG  SI.SPR.PC40.ZG  SI.SPR.PC40.05  \
# CountryCode Year
# ABW         1960             NaN             NaN             NaN
#             1961             NaN             NaN             NaN
#             1962             NaN             NaN             NaN
#             1963             NaN             NaN             NaN
#             1964             NaN             NaN             NaN
# ...                          ...             ...             ...
# ZWE         2006             NaN             NaN             NaN
#             2007             NaN             NaN             NaN
#             2008             NaN             NaN             NaN
#             2009             NaN             NaN             NaN
#             2010             NaN             NaN             NaN
#
# IndicatorCode     SI.SPR.PCAP.05  LP.LPI.LOGS.XQ  LP.LPI.TRAC.XQ  \
# CountryCode Year
# ABW         1960             NaN             NaN             NaN
#             1961             NaN             NaN             NaN
#             1962             NaN             NaN             NaN
#             1963             NaN             NaN             NaN
#             1964             NaN             NaN             NaN
# ...                          ...             ...             ...
# ZWE         2006             NaN             NaN             NaN
#             2007             NaN            2.21            2.64
#             2008             NaN             NaN             NaN
#             2009             NaN             NaN             NaN
#             2010             NaN             NaN             NaN
#
# IndicatorCode     LP.LPI.CUST.XQ  LP.LPI.INFR.XQ  LP.LPI.OVRL.XQ  \
# CountryCode Year
# ABW         1960             NaN             NaN             NaN
#             1961             NaN             NaN             NaN
#             1962             NaN             NaN             NaN
#             1963             NaN             NaN             NaN
#             1964             NaN             NaN             NaN
# ...                          ...             ...             ...
# ZWE         2006             NaN             NaN             NaN
#             2007            1.92            1.87            2.29
#             2008             NaN             NaN             NaN
#             2009             NaN             NaN             NaN
#             2010             NaN             NaN             NaN
#
# IndicatorCode     per_allsp.ben_q1_tot  ...  NV.IND.TOTL.KD.ZG  IC.EXP.DURS  \
# CountryCode Year                        ...
# ABW         1960                   NaN  ...                NaN          NaN
#             1961                   NaN  ...                NaN          NaN
#             1962                   NaN  ...                NaN          NaN
#             1963                   NaN  ...                NaN          NaN
#             1964                   NaN  ...                NaN          NaN
# ...                                ...  ...                ...          ...
# ZWE         2006                   NaN  ...          -4.152000         52.0
#             2007                   NaN  ...          -3.767697         52.0
#             2008                   NaN  ...         -20.914062         53.0
#             2009                   NaN  ...           9.660698         53.0
#             2010                   NaN  ...          14.887979         53.0
#
# IndicatorCode     IC.TAX.GIFT.ZS  IQ.CPA.FISP.XQ  IQ.WEF.PORT.XQ  \
# CountryCode Year
# ABW         1960             NaN             NaN             NaN
#             1961             NaN             NaN             NaN
#             1962             NaN             NaN             NaN
#             1963             NaN             NaN             NaN
#             1964             NaN             NaN             NaN
# ...                          ...             ...             ...
# ZWE         2006             NaN             1.0             NaN
#             2007             NaN             1.0        4.083333
#             2008             NaN             1.0        4.270329
#             2009             NaN             2.0        4.417178
#             2010             NaN             2.0        4.409526
#
# IndicatorCode     NE.IMP.GNFS.KD.ZG  FS.AST.DOMS.GD.ZS  NE.CON.PRVT.KD.ZG  \
# CountryCode Year
# ABW         1960                NaN                NaN                NaN
#             1961                NaN                NaN                NaN
#             1962                NaN                NaN                NaN
#             1963                NaN                NaN                NaN
#             1964                NaN                NaN                NaN
# ...                             ...                ...                ...
# ZWE         2006          -6.680595                NaN           4.992830
#             2007         -12.666982                NaN          -6.923020
#             2008          11.647857                NaN          -3.137561
#             2009          40.964584                NaN          31.877126
#             2010          53.386946                NaN          -0.096450
#
# IndicatorCode     SH.MED.BEDS.ZS  nextyearGDPgrowth
# CountryCode Year
# ABW         1960             NaN                NaN
#             1961             NaN                NaN
#             1962             NaN                NaN
#             1963             NaN                NaN
#             1964             NaN                NaN
# ...                          ...                ...
# ZWE         2006             3.0          -3.653327
#             2007             NaN         -17.668947
#             2008             NaN           5.984391
#             2009             NaN          11.375921
#             2010             NaN                NaN
#
# [12597 rows x 50 columns]

# %%
print(country_indicators_table.shape)
country_indicators_table.tail()
# Out:
# (12597, 1329)
# IndicatorCode     AG.AGR.TRAC.NO  AG.CON.FERT.PT.ZS  AG.CON.FERT.ZS  \
# CountryCode Year
# ZWE         2006             NaN         210.442742       32.356341
#             2007             NaN         171.109177       27.035250
#             2008             NaN         147.903481       21.994118
#             2009             NaN         186.693038       28.778049
#             2010             NaN         215.715190       34.083000
#
# IndicatorCode     AG.LND.AGRI.K2  AG.LND.AGRI.ZS  AG.LND.ARBL.HA  \
# CountryCode Year
# ZWE         2006        163000.0       42.135195       4100000.0
#             2007        162000.0       41.876696       4000000.0
#             2008        164500.0       42.522942       4250000.0
#             2009        163000.0       42.135195       4100000.0
#             2010        162000.0       41.876696       4000000.0
#
# IndicatorCode     AG.LND.ARBL.HA.PC  AG.LND.ARBL.ZS  AG.LND.CREL.HA  \
# CountryCode Year
# ZWE         2006           0.312311       10.598423       2289312.0
#             2007           0.300802       10.339925       1949453.0
#             2008           0.314921       10.986170       2235440.0
#             2009           0.298812       10.598423       2080405.0
#             2010           0.286248       10.339925       1891766.0
#
# IndicatorCode     AG.LND.CROP.ZS  ...  per_lm_alllm.adq_pop_tot  \
# CountryCode Year                  ...
# ZWE         2006        0.258498  ...                       NaN
#             2007        0.258498  ...                       NaN
#             2008        0.258498  ...                       NaN
#             2009        0.258498  ...                       NaN
#             2010        0.258498  ...                       NaN
#
# IndicatorCode     per_lm_alllm.ben_q1_tot  per_lm_alllm.cov_pop_tot  \
# CountryCode Year
# ZWE         2006                      NaN                       NaN
#             2007                      NaN                       NaN
#             2008                      NaN                       NaN
#             2009                      NaN                       NaN
#             2010                      NaN                       NaN
#
# IndicatorCode     per_sa_allsa.adq_pop_tot  per_sa_allsa.ben_q1_tot  \
# CountryCode Year
# ZWE         2006                       NaN                      NaN
#             2007                       NaN                      NaN
#             2008                       NaN                      NaN
#             2009                       NaN                      NaN
#             2010                       NaN                      NaN
#
# IndicatorCode     per_sa_allsa.cov_pop_tot  per_si_allsi.adq_pop_tot  \
# CountryCode Year
# ZWE         2006                       NaN                       NaN
#             2007                       NaN                       NaN
#             2008                       NaN                       NaN
#             2009                       NaN                       NaN
#             2010                       NaN                       NaN
#
# IndicatorCode     per_si_allsi.ben_q1_tot  per_si_allsi.cov_pop_tot  \
# CountryCode Year
# ZWE         2006                      NaN                       NaN
#             2007                      NaN                       NaN
#             2008                      NaN                       NaN
#             2009                      NaN                       NaN
#             2010                      NaN                       NaN
#
# IndicatorCode     nextyearGDPgrowth
# CountryCode Year
# ZWE         2006          -3.653327
#             2007         -17.668947
#             2008           5.984391
#             2009          11.375921
#             2010                NaN
#
# [5 rows x 1329 columns]

# %% [markdown]
# As we can see,

# %%
cor_matrix_indicators = country_indicators_table.corr()

# %%
cor_vector_indicators = cor_matrix_indicators["nextyearGDPgrowth"]

# %%
df_indicators_final = pd.DataFrame (cor_vector_indicators, index = cor_matrix_indicators.columns)
df_indicators_final['nextyearGDPgrowth.abs'] = abs(cor_vector_indicators)
df_indicators_final = df_indicators_final.sort_values(by='nextyearGDPgrowth.abs',ascending=0).head(50)

# %%
indicadors = df_indicators_final.index

# %%
country_indicators_table=country_indicators_table[indicadors]
country_indicators_table.tail()
# Out:
# IndicatorCode     nextyearGDPgrowth  SI.SPR.PCAP.ZG  SI.SPR.PC40.ZG  \
# CountryCode Year
# ZWE         2006          -3.653327             NaN             NaN
#             2007         -17.668947             NaN             NaN
#             2008           5.984391             NaN             NaN
#             2009          11.375921             NaN             NaN
#             2010                NaN             NaN             NaN
#
# IndicatorCode     SI.SPR.PC40.05  SI.SPR.PCAP.05  LP.LPI.LOGS.XQ  \
# CountryCode Year
# ZWE         2006             NaN             NaN             NaN
#             2007             NaN             NaN            2.21
#             2008             NaN             NaN             NaN
#             2009             NaN             NaN             NaN
#             2010             NaN             NaN             NaN
#
# IndicatorCode     LP.LPI.TRAC.XQ  LP.LPI.CUST.XQ  LP.LPI.INFR.XQ  \
# CountryCode Year
# ZWE         2006             NaN             NaN             NaN
#             2007            2.64            1.92            1.87
#             2008             NaN             NaN             NaN
#             2009             NaN             NaN             NaN
#             2010             NaN             NaN             NaN
#
# IndicatorCode     LP.LPI.OVRL.XQ  ...  IC.IMP.DURS  NV.IND.TOTL.KD.ZG  \
# CountryCode Year                  ...
# ZWE         2006             NaN  ...         67.0          -4.152000
#             2007            2.29  ...         67.0          -3.767697
#             2008             NaN  ...         73.0         -20.914062
#             2009             NaN  ...         73.0           9.660698
#             2010             NaN  ...         73.0          14.887979
#
# IndicatorCode     IC.EXP.DURS  IC.TAX.GIFT.ZS  IQ.CPA.FISP.XQ  IQ.WEF.PORT.XQ  \
# CountryCode Year
# ZWE         2006         52.0             NaN             1.0             NaN
#             2007         52.0             NaN             1.0        4.083333
#             2008         53.0             NaN             1.0        4.270329
#             2009         53.0             NaN             2.0        4.417178
#             2010         53.0             NaN             2.0        4.409526
#
# IndicatorCode     NE.IMP.GNFS.KD.ZG  FS.AST.DOMS.GD.ZS  NE.CON.PRVT.KD.ZG  \
# CountryCode Year
# ZWE         2006          -6.680595                NaN           4.992830
#             2007         -12.666982                NaN          -6.923020
#             2008          11.647857                NaN          -3.137561
#             2009          40.964584                NaN          31.877126
#             2010          53.386946                NaN          -0.096450
#
# IndicatorCode     SH.MED.BEDS.ZS
# CountryCode Year
# ZWE         2006             3.0
#             2007             NaN
#             2008             NaN
#             2009             NaN
#             2010             NaN
#
# [5 rows x 50 columns]

# %%
nextyearGDP = country_indicators_table.pop("nextyearGDPgrowth")
country_indicators_table["nextyearGDPgrowth"]=nextyearGDP

# %%
country_indicators_table.shape
# Out:
# (12597, 50)

# %%
classList = np.array(list(map(list, country_indicators_table.index)))

'''
country_indicators_table[:,0] #numeric country code
country_indicators_table[:,1] #year
country_indicators_table[:,-1] #GDP to predict
'''
# Out:
# '\ncountry_indicators_table[:,0] #numeric country code\ncountry_indicators_table[:,1] #year\ncountry_indicators_table[:,-1] #GDP to predict\n'

# %%
countryCodes_num, countryDict = encode(classList[:,0])
years_num = np.array(list(map(int, classList[:,1])))[:,np.newaxis]
countryCodes_num = np.array(countryCodes_num)[:,np.newaxis]

# %%
countryCodes_num
# Out:
# array([[  0],
#        [  0],
#        [  0],
#        ...,
#        [246],
#        [246],
#        [246]])

# %%
countryDict
# Out:
# {'ABW': 0,
#  'ADO': 1,
#  'AFG': 2,
#  'AGO': 3,
#  'ALB': 4,
#  'ARB': 5,
#  'ARE': 6,
#  'ARG': 7,
#  'ARM': 8,
#  'ASM': 9,
#  'ATG': 10,
#  'AUS': 11,
#  'AUT': 12,
#  'AZE': 13,
#  'BDI': 14,
#  'BEL': 15,
#  'BEN': 16,
#  'BFA': 17,
#  'BGD': 18,
#  'BGR': 19,
#  'BHR': 20,
#  'BHS': 21,
#  'BIH': 22,
#  'BLR': 23,
#  'BLZ': 24,
#  'BMU': 25,
#  'BOL': 26,
#  'BRA': 27,
#  'BRB': 28,
#  'BRN': 29,
#  'BTN': 30,
#  'BWA': 31,
#  'CAF': 32,
#  'CAN': 33,
#  'CEB': 34,
#  'CHE': 35,
#  'CHI': 36,
#  'CHL': 37,
#  'CHN': 38,
#  'CIV': 39,
#  'CMR': 40,
#  'COG': 41,
#  'COL': 42,
#  'COM': 43,
#  'CPV': 44,
#  'CRI': 45,
#  'CSS': 46,
#  'CUB': 47,
#  'CUW': 48,
#  'CYM': 49,
#  'CYP': 50,
#  'CZE': 51,
#  'DEU': 52,
#  'DJI': 53,
#  'DMA': 54,
#  'DNK': 55,
#  'DOM': 56,
#  'DZA': 57,
#  'EAP': 58,
#  'EAS': 59,
#  'ECA': 60,
#  'ECS': 61,
#  'ECU': 62,
#  'EGY': 63,
#  'EMU': 64,
#  'ERI': 65,
#  'ESP': 66,
#  'EST': 67,
#  'ETH': 68,
#  'EUU': 69,
#  'FCS': 70,
#  'FIN': 71,
#  'FJI': 72,
#  'FRA': 73,
#  'FRO': 74,
#  'FSM': 75,
#  'GAB': 76,
#  'GBR': 77,
#  'GEO': 78,
#  'GHA': 79,
#  'GIN': 80,
#  'GMB': 81,
#  'GNB': 82,
#  'GNQ': 83,
#  'GRC': 84,
#  'GRD': 85,
#  'GRL': 86,
#  'GTM': 87,
#  'GUM': 88,
#  'GUY': 89,
#  'HIC': 90,
#  'HKG': 91,
#  'HND': 92,
#  'HPC': 93,
#  'HRV': 94,
#  'HTI': 95,
#  'HUN': 96,
#  'IDN': 97,
#  'IMY': 98,
#  'IND': 99,
#  'IRL': 100,
#  'IRN': 101,
#  'IRQ': 102,
#  'ISL': 103,
#  'ISR': 104,
#  'ITA': 105,
#  'JAM': 106,
#  'JOR': 107,
#  'JPN': 108,
#  'KAZ': 109,
#  'KEN': 110,
#  'KGZ': 111,
#  'KHM': 112,
#  'KIR': 113,
#  'KNA': 114,
#  'KOR': 115,
#  'KSV': 116,
#  'KWT': 117,
#  'LAC': 118,
#  'LAO': 119,
#  'LBN': 120,
#  'LBR': 121,
#  'LBY': 122,
#  'LCA': 123,
#  'LCN': 124,
#  'LDC': 125,
#  'LIC': 126,
#  'LIE': 127,
#  'LKA': 128,
#  'LMC': 129,
#  'LMY': 130,
#  'LSO': 131,
#  'LTU': 132,
#  'LUX': 133,
#  'LVA': 134,
#  'MAC': 135,
#  'MAF': 136,
#  'MAR': 137,
#  'MCO': 138,
#  'MDA': 139,
#  'MDG': 140,
#  'MDV': 141,
#  'MEA': 142,
#  'MEX': 143,
#  'MHL': 144,
#  'MIC': 145,
#  'MKD': 146,
#  'MLI': 147,
#  'MLT': 148,
#  'MMR': 149,
#  'MNA': 150,
#  'MNE': 151,
#  'MNG': 152,
#  'MNP': 153,
#  'MOZ': 154,
#  'MRT': 155,
#  'MUS': 156,
#  'MWI': 157,
#  'MYS': 158,
#  'NAC': 159,
#  'NAM': 160,
#  'NCL': 161,
#  'NER': 162,
#  'NGA': 163,
#  'NIC': 164,
#  'NLD': 165,
#  'NOC': 166,
#  'NOR': 167,
#  'NPL': 168,
#  'NZL': 169,
#  'OEC': 170,
#  'OED': 171,
#  'OMN': 172,
#  'OSS': 173,
#  'PAK': 174,
#  'PAN': 175,
#  'PER': 176,
#  'PHL': 177,
#  'PLW': 178,
#  'PNG': 179,
#  'POL': 180,
#  'PRI': 181,
#  'PRK': 182,
#  'PRT': 183,
#  'PRY': 184,
#  'PSS': 185,
#  'PYF': 186,
#  'QAT': 187,
#  'ROM': 188,
#  'RUS': 189,
#  'RWA': 190,
#  'SAS': 191,
#  'SAU': 192,
#  'SDN': 193,
#  'SEN': 194,
#  'SGP': 195,
#  'SLB': 196,
#  'SLE': 197,
#  'SLV': 198,
#  'SMR': 199,
#  'SOM': 200,
#  'SRB': 201,
#  'SSA': 202,
#  'SSD': 203,
#  'SSF': 204,
#  'SST': 205,
#  'STP': 206,
#  'SUR': 207,
#  'SVK': 208,
#  'SVN': 209,
#  'SWE': 210,
#  'SWZ': 211,
#  'SXM': 212,
#  'SYC': 213,
#  'SYR': 214,
#  'TCA': 215,
#  'TCD': 216,
#  'TGO': 217,
#  'THA': 218,
#  'TJK': 219,
#  'TKM': 220,
#  'TMP': 221,
#  'TON': 222,
#  'TTO': 223,
#  'TUN': 224,
#  'TUR': 225,
#  'TUV': 226,
#  'TZA': 227,
#  'UGA': 228,
#  'UKR': 229,
#  'UMC': 230,
#  'URY': 231,
#  'USA': 232,
#  'UZB': 233,
#  'VCT': 234,
#  'VEN': 235,
#  'VIR': 236,
#  'VNM': 237,
#  'VUT': 238,
#  'WBG': 239,
#  'WLD': 240,
#  'WSM': 241,
#  'YEM': 242,
#  'ZAF': 243,
#  'ZAR': 244,
#  'ZMB': 245,
#  'ZWE': 246}

# %%
years_num
# Out:
# array([[1960],
#        [1961],
#        [1962],
#        ...,
#        [2008],
#        [2009],
#        [2010]])

# %%
values = country_indicators_table.to_numpy()
country_indicators= np.concatenate((countryCodes_num,years_num,values), axis=1)

# %%
values
# Out:
# array([[        nan,         nan,         nan, ...,         nan,
#                 nan,         nan],
#        [        nan,         nan,         nan, ...,         nan,
#                 nan,         nan],
#        [        nan,         nan,         nan, ...,         nan,
#                 nan,         nan],
#        ...,
#        [        nan,         nan,         nan, ..., -3.13756141,
#                 nan,  5.98439075],
#        [        nan,         nan,         nan, ..., 31.87712627,
#                 nan, 11.37592123],
#        [        nan,         nan,         nan, ..., -0.09645039,
#                 nan,         nan]])

# %%
country_indicators
# Out:
# array([[ 0.00000000e+00,  1.96000000e+03,             nan, ...,
#                     nan,             nan,             nan],
#        [ 0.00000000e+00,  1.96100000e+03,             nan, ...,
#                     nan,             nan,             nan],
#        [ 0.00000000e+00,  1.96200000e+03,             nan, ...,
#                     nan,             nan,             nan],
#        ...,
#        [ 2.46000000e+02,  2.00800000e+03,             nan, ...,
#         -3.13756141e+00,             nan,  5.98439075e+00],
#        [ 2.46000000e+02,  2.00900000e+03,             nan, ...,
#          3.18771263e+01,             nan,  1.13759212e+01],
#        [ 2.46000000e+02,  2.01000000e+03,             nan, ...,
#         -9.64503944e-02,             nan,             nan]])

# %% [markdown]
# QUITAMOS LOS NANs #Reemplazamos los Nan por la media correspondiente de cada columna

# %%
country_indicators_mean = np.nanmean(country_indicators, axis=0)
inds = np.where(np.isnan(country_indicators))
country_indicators[inds] = np.take(country_indicators_mean, inds[1])
country_indicators_mean = country_indicators

# %%
indexes_2010_mean = np.where((country_indicators_mean[:,1]==2010))
country_indicators_2010_mean = country_indicators_mean[indexes_2010_mean]

country_indicators_no2010_mean = np.delete(country_indicators_mean, indexes_2010_mean, 0)

# %%
X_2010_mean = country_indicators_2010_mean[:,:-1]

X_mean = country_indicators_no2010_mean[:,:-1]
y_mean = country_indicators_no2010_mean[:,-1]

# %%
X_train_mean, X_test_mean, y_train_mean, y_test_mean = train_test_split(X_mean,y_mean,test_size=0.2)
print(X_train_mean.shape)
print(X_test_mean.shape)
print(y_train_mean.shape)
print(y_test_mean.shape)
# Out:
# (9880, 51)
# (2470, 51)
# (9880,)
# (2470,)

# %%
gbreg_es_mean = GradientBoostingRegressor(max_depth=2, n_estimators=2000,
                                     validation_fraction=0.05,n_iter_no_change=25,
                                     learning_rate=0.1, random_state=42,criterion="mse")

# %%
gbreg_es_mean = GradientBoostingRegressor(max_depth=10, n_estimators=100,
                                     learning_rate=0.1,loss="ls")

# %%
gbreg_es_mean.fit(X_train_mean,y_train_mean)
print('n_estimators_:',gbreg_es_mean.n_estimators_)
print('MSE is:',np.sqrt(mean_squared_error(y_test_mean,gbreg_es_mean.predict(X_test_mean))))
# Out:
# n_estimators_: 100
# MSE is: 5.3679141859730715

# %%
pred_vs_real_mean = pd.DataFrame(y_test_mean,columns=['real'])
pred_vs_real_mean['predictions'] = gbreg_es_mean.predict(X_test_mean)

# %%
pred_vs_real_mean.head()
# Out:
#         real  predictions
# 0   1.269758     2.554372
# 1   6.511970     5.153714
# 2  -1.251597     2.885388
# 3  11.018512     2.711637
# 4   3.974739     3.460978

# %%
gbreg_es_mean.predict(X_2010_mean)
# Out:
# array([ 3.97517717e+00,  1.24919527e+00,  7.00718902e+00,  3.76242616e+00,
#         3.36767870e+00,  4.50707021e+00,  6.55737919e+00,  6.83345492e+00,
#         3.33736690e+00,  3.97517717e+00, -3.13129187e+00,  3.60962221e+00,
#         3.12333593e+00,  5.97809925e+00,  7.48602656e+00,  1.55839894e+00,
#         4.47817216e+00,  6.31272688e+00,  5.02167494e+00,  4.70929551e-01,
#         2.44381645e+00,  2.76420251e+00,  2.52637083e+00,  6.24072276e+00,
#         1.85441422e+00,  6.15323592e-01,  3.53679454e+00,  5.99437273e+00,
#         2.20555806e+00,  1.15336951e+00,  9.90732727e+00,  7.87600011e+00,
#         5.92579859e+00,  1.88285501e+00,  2.49812907e+00,  1.44478117e+00,
#         3.93074453e+00,  5.89016369e+00,  1.00312363e+01,  3.72633473e+00,
#         3.69836587e+00,  4.97930682e+00,  3.63400143e+00,  4.76922740e+00,
#         3.11696452e+00,  2.14130833e+00,  3.51078953e+00,  3.12357445e+00,
#         3.93074453e+00,  1.21065952e-02,  4.25072966e+00,  2.47413021e+00,
#         2.69898802e+00,  3.50199734e+00,  2.56946444e+00,  2.77103509e+00,
#         5.83800774e+00,  4.17978042e+00,  6.50499341e+00,  5.58452745e+00,
#         4.98117146e+00,  3.14713788e+00,  5.05227754e+00,  5.20027008e+00,
#         2.64889464e+00,  2.96434654e+00,  9.84122985e-01,  3.33342011e+00,
#         8.07106570e+00,  2.67356152e+00,  5.35089967e+00,  2.24544229e+00,
#         3.13510617e+00,  1.23479807e+00,  4.00266955e+00,  3.55919650e+00,
#         8.97264671e+00,  2.51043868e+00,  4.91386116e+00,  7.88340275e+00,
#         3.15522720e+00,  4.79576447e+00,  4.43419250e+00, -6.39795739e-01,
#        -6.06417375e+00,  2.79571286e+00,  3.96082250e+00,  3.22693384e+00,
#         3.91239760e+00,  6.11275323e+00,  2.04341674e+00,  5.78231316e+00,
#         3.43972956e+00,  5.79014142e+00,  3.60651089e+00,  4.91636155e+00,
#         2.73607970e+00,  5.66614504e+00,  4.21168445e+00,  8.44723790e+00,
#         2.57461242e+00,  5.71665629e+00,  6.63899736e+00, -1.23276380e+00,
#         4.04929113e+00,  2.18918085e+00,  6.10291677e+00,  3.91312739e+00,
#         3.39844700e+00,  4.66584414e+00,  6.11943001e+00,  3.03897489e+00,
#         6.73336888e+00,  2.10914888e+00,  1.81159695e+00,  6.54423140e+00,
#         4.20036801e+00,  1.05001953e+01,  5.95393393e+00,  2.83560553e+00,
#         7.78843370e+00,  5.81192220e+00,  5.47506140e+00,  2.04716934e+00,
#         4.55546172e+00,  6.05233093e+00,  7.37282075e+00,  4.08317744e+00,
#         7.81414711e+00,  7.06679388e+00,  7.72967174e+00,  9.32366922e+00,
#         2.83256139e+00,  4.81114938e+00, -1.47155527e+01,  1.48027444e+01,
#         4.08317744e+00,  4.04819026e+00,  4.06267872e+00,  5.46421685e+00,
#         7.19873109e+00,  4.90634589e+00,  4.91992396e+00,  6.21253021e+00,
#         2.28970246e+00,  7.14055304e+00,  3.79733841e+00,  3.03991170e+00,
#         4.56870119e+00,  4.92109772e+00,  5.79298011e+00,  4.67266678e+00,
#         6.89934098e+00,  4.04457416e+00,  7.17587519e+00,  5.13527812e+00,
#         4.53209966e+00,  7.34912445e+00,  6.06509003e+00,  3.03573915e+00,
#         6.55498321e+00,  3.92714700e+00,  1.11118770e+01,  6.11080332e+00,
#         5.09665675e+00,  3.13289791e+00,  4.94339044e+00,  2.81121894e+00,
#         3.99741699e+00,  3.08106300e+00,  2.33252785e+00,  2.80117775e+00,
#        -1.50075825e-01,  4.99413150e+00,  5.72160328e+00,  4.06288078e+00,
#         5.96355345e+00,  6.84797199e+00,  3.65489533e+00,  6.72013364e+00,
#         3.33629613e+00,  2.60115383e+00,  3.98697915e+00,  7.66711051e-02,
#         8.00257485e+00,  4.07079987e+00,  4.04733470e+00,  7.85564704e+00,
#         3.22816393e+00,  5.90269654e+00,  7.19690481e+00,  8.41362859e+00,
#         4.48499326e+00,  4.41114805e+00,  5.07357200e+00,  8.62634716e+00,
#         2.38507415e+00,  1.20385058e+01,  2.96002077e+00,  4.09570660e+00,
#         3.29261631e+00,  2.97967993e+00,  6.46263344e+00,  4.42182779e+00,
#         7.08479840e+00,  3.76069388e+00,  4.85708152e+00,  3.48260636e+00,
#         5.28312756e+00,  9.00060034e-01,  1.91562885e+00,  8.26608678e+00,
#         4.14902731e+00,  7.60555141e+00,  4.26213193e+00,  4.10988593e+00,
#         3.00519671e+00,  4.23366535e+00,  6.44214689e+00,  6.72409284e-01,
#         5.67248696e+00,  6.32308335e+00,  4.35708358e+00,  4.39029980e+00,
#         2.57731758e+00,  7.47812940e+00,  2.01386957e+00,  4.17593470e+00,
#         6.96033681e+00,  4.80508436e+00,  6.42553845e+00,  4.21778227e+00,
#         3.41053156e+00,  6.12217524e+00,  5.53418743e-01,  2.06510587e+00,
#         4.15575917e+00,  5.57958600e+00,  4.87966432e+00,  3.77318652e+00,
#         3.59421735e+00,  4.07635653e+00,  6.40250371e+00,  4.66399814e+00,
#         9.02188965e+00,  6.18616609e+00,  2.91412042e+00])

# %% [markdown]
# QUITAMOS LOS NANs #Reemplazamos los Nan por 0

# %%
country_indicators_0 = np.nan_to_num(country_indicators, nan = 0.0)

# %%
indexes_2010_0 = np.where((country_indicators_0[:,1]==2010))
country_indicators_2010_0 = country_indicators_0[indexes_2010_0]

country_indicators_no2010_0 = np.delete(country_indicators_0, indexes_2010_0, 0)

# %%
X_2010_0 = country_indicators_2010_0[:,:-1]

X_0 = country_indicators_no2010_0[:,:-1]
y_0 = country_indicators_no2010_0[:,-1]

# %%
X_train_0, X_test_0, y_train_0, y_test_0 = train_test_split(X_0,y_0,test_size=0.2)
print(X_train_0.shape)
print(X_test_0.shape)
print(y_train_0.shape)
print(y_test_0.shape)
# Out:
# (9880, 51)
# (2470, 51)
# (9880,)
# (2470,)

# %%
gbreg_es_0 = GradientBoostingRegressor(max_depth=2, n_estimators=2000,
                                     validation_fraction=0.05,n_iter_no_change=25,
                                     learning_rate=0.1, random_state=42,criterion="mse")

# %%
gbreg_es_0.fit(X_train_0,y_train_0)
print('n_estimators_:',gbreg_es_0.n_estimators_)
print('MSE is:',np.sqrt(mean_squared_error(y_test_0,gbreg_es_0.predict(X_test_0))))
# Out:
# n_estimators_: 116
# MSE is: 5.323071780250422

# %%
pred_vs_real_0 = pd.DataFrame(y_test_0,columns=['real'])
pred_vs_real_0['predictions'] = gbreg_es_0.predict(X_test_0)

# %%
pred_vs_real_0.head()
# Out:
#         real  predictions
# 0  12.064409     4.402542
# 1   3.436426     3.437717
# 2   3.396535     3.681704
# 3   0.955757    -0.608361
# 4   4.468129     3.392927

# %%
gbreg_es_0.predict(X_2010_0)
# Out:
# array([ 4.2272525 ,  2.57661396,  6.84834431,  4.85887628,  3.98184919,
#         4.50396615,  2.96267434,  6.94266137,  4.04357193,  4.2272525 ,
#        -0.14847554,  3.10139352,  3.28897763,  4.71806458,  5.68310865,
#         3.64129818,  3.7322873 ,  7.15801802,  5.11048702,  1.9244177 ,
#         4.69982771,  3.47778493,  3.05589523,  7.64292166,  3.89665882,
#         1.61331423,  4.83214284,  6.20523953,  3.269934  ,  3.2334614 ,
#        15.49791333,  6.14394679,  4.59529575,  3.81178476,  3.33981674,
#         3.62420065,  4.2272525 ,  5.0660983 ,  8.07734861,  3.38846165,
#         4.85225169,  7.06723225,  4.60145238,  4.92696166,  3.31675186,
#         4.85494053,  2.99316081,  4.20210532,  4.2272525 ,  3.26395277,
#         2.72540874,  3.75658183,  4.41661809,  4.20425531,  3.37893635,
#         2.77941581,  6.5907213 ,  4.27711673,  6.7560456 ,  6.17632765,
#         5.5449466 ,  3.33981674,  4.53212509,  5.2782856 ,  3.28897763,
#         4.34733678,  1.9244177 ,  4.00915898,  8.86280941,  3.33981674,
#         5.46685315,  4.33417131,  3.98184919,  2.30421096,  4.2272525 ,
#         4.17050717,  6.81840258,  2.99345458,  5.3329698 ,  6.84314352,
#         4.48762245,  5.73110236,  4.81357898,  4.82254157, -1.67757144,
#         2.36257519,  4.2272525 ,  4.286803  ,  4.2272525 ,  4.57522538,
#         3.81178476,  5.92303149,  5.09759535,  6.13386108,  1.66744803,
#         3.26806168,  2.87437432,  6.08803869,  4.2272525 ,  8.47670292,
#         2.41031079,  5.07062003,  6.19387777,  2.0320887 ,  4.9244225 ,
#         2.70583384,  2.55473139,  1.94754491,  4.76739296,  5.79228751,
#         6.94582988,  2.86213109,  6.38575327,  3.41535866,  1.33683481,
#         5.55550163,  3.95579745,  2.76322973,  5.29785151,  6.83014824,
#         5.52459491,  5.06498131,  4.4765388 ,  2.30856812,  5.29785151,
#         6.08302197,  6.50828012,  4.2272525 ,  6.60265834,  6.17013544,
#         6.43560847,  6.95020794,  3.52482863,  4.59655272,  2.31523814,
#        22.11158686,  4.2272525 ,  5.01988672,  4.2272525 ,  6.37465087,
#         3.76631349,  4.87303215,  4.60854702,  5.44706519,  3.95920666,
#         6.43560847,  4.63075777,  4.95940066,  4.55954204,  5.0903453 ,
#         5.23217513,  2.88735475,  6.38600568,  4.2272525 ,  5.75666951,
#         5.16208801,  4.33320899,  6.61386078,  6.66833472,  3.28897763,
#         5.44841293,  4.2272525 ,  7.07720253,  6.63893148,  4.42708867,
#         3.16185172,  5.68523227,  3.00188816,  5.29364871,  2.96699992,
#         3.81178476,  3.81178476,  5.11713393,  5.07720756,  3.7333507 ,
#         6.01580246,  6.74950383,  7.03953047,  3.68617682,  6.36029694,
#         4.52175542,  2.57661396,  4.2272525 ,  2.30421096,  8.91050725,
#         4.20898395,  4.2272525 , 11.79167762,  2.01357721,  4.58318974,
#         6.78403777,  6.31042111,  4.42279704,  4.68027796,  4.53555638,
#         8.6259373 ,  5.67419145,  6.03133892,  3.37075893,  3.95077308,
#         4.2272525 ,  3.05589523,  5.5022373 ,  5.06061625,  5.5022373 ,
#         3.92036496,  4.78926415,  5.35114702,  5.28873892,  2.19627202,
#         5.73156237,  3.45593375,  4.2272525 ,  4.9820345 ,  4.58166685,
#         4.2272525 ,  8.72458571,  4.53555638,  6.30080485,  5.69166274,
#         6.44020807,  5.83612228,  4.8205852 ,  2.72418732,  0.74044149,
#         6.73937285,  1.61331423,  6.57381199,  6.61267242,  4.71825286,
#         6.43560847,  6.68753993,  3.56545706,  5.90892548,  2.30856812,
#         2.9401919 ,  4.2272525 ,  5.11673051,  3.75426435,  3.42871205,
#         4.46567572,  3.269934  ,  4.20425531,  2.67272868,  6.95277572,
#         8.40140202,  7.91830468])

# %% [markdown]
# NO HACE FALTA QUITAR NANs, usamos otra libreria LightGBM

# %%
indexes_2010 = np.where((country_indicators[:,1]==2010))
country_indicators_2010 = country_indicators[indexes_2010]

country_indicators_no2010 = np.delete(country_indicators, indexes_2010, 0)

# %%
X_2010 = country_indicators_2010[:,:-1]

X = country_indicators_no2010[:,:-1]
y = country_indicators_no2010[:,-1]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (9880, 51)
# (2470, 51)
# (9880,)
# (2470,)

# %%
import lightgbm as lgb
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-43-5dacb4a27011> in <module>
# ----> 1 import lightgbm as lgb
#
# ModuleNotFoundError: No module named 'lightgbm'

# %%
gbreg_es = lgb.LGBMRegressor(boosting_type = 'gbdt', objective = 'regression', num_leaves = 1200,
                                learning_rate = 0.1, n_estimators = 2000, max_depth = 2,
                                metric = 'mse', bagging_fraction = 0.8, feature_fraction = 0.8, reg_lambda = 0.9)

gbreg_es.fit(X_train, y_train)

# %%
print('MSE is:',np.sqrt(mean_squared_error(y_test,gbreg_es.predict(X_test))))

# %%
model = lgb.LGBMRegressor()

# %%
model.fit(X_train, y_train)
