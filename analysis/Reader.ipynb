# %%
import sys
sys.path.append("..")

# %%
import utils
from utils import config as cn
import sqlite3
import pandas as pd

# %% [markdown]
# Accessing database and loading the data we will use as pd.dataframe()

# %%
dbpath=cn.DATABASE_PATH
print(dbpath)
# Out:
# C:\Users\Oriol\Desktop\final_project_skeleton\gdp_growth_forecast\db.sqlite3

# %%
db=sqlite3.connect(cn.DATABASE_PATH)

# %%
cur = db.cursor()

# %%
di = pd.read_sql_query("SELECT * from indicators", db)
dcountry=

# %%
di
# Out:
#              IndicatorCode                                              Topic  \
# 0           BN.KLT.DINV.CD  Economic Policy & Debt: Balance of payments: C...
# 1     BX.KLT.DINV.WD.GD.ZS  Economic Policy & Debt: Balance of payments: C...
# 2        BX.KLT.DINV.CD.WD  Economic Policy & Debt: Balance of payments: C...
# 3        BM.KLT.DINV.GD.ZS  Economic Policy & Debt: Balance of payments: C...
# 4           BN.TRF.KOGT.CD  Economic Policy & Debt: Balance of payments: C...
# ...                    ...                                                ...
# 1340  SL.UEM.1524.FE.NE.ZS            Social Protection & Labor: Unemployment
# 1341     SL.UEM.1524.MA.ZS            Social Protection & Labor: Unemployment
# 1342  SL.UEM.1524.MA.NE.ZS            Social Protection & Labor: Unemployment
# 1343        SL.UEM.1524.ZS            Social Protection & Labor: Unemployment
# 1344     SL.UEM.1524.NE.ZS            Social Protection & Labor: Unemployment
#
# ...

# %%
dfcontain = df['Topic'].str.contains("Economic" or "GDP" or "salary" or "employment")

# %%
dfcontain
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 1340    False
# 1341    False
# 1342    False
# 1343    False
# 1344    False
# Name: Topic, Length: 1345, dtype: bool

# %% [markdown]
# hasta aqui, mierda menos lo de cargar

# %%
country = "MNG"

# %%
di = pd.read_sql_query("SELECT * from CountryIndicators", db)

# %%
di
# Out:
#         CountryCode      IndicatorCode  Year         Value
# 0               ARB        SP.ADO.TFRT  1960  1.335609e+02
# 1               ARB        SP.POP.DPND  1960  8.779760e+01
# 2               ARB     SP.POP.DPND.OL  1960  6.634579e+00
# 3               ARB     SP.POP.DPND.YG  1960  8.102333e+01
# 4               ARB     MS.MIL.XPRT.KD  1960  3.000000e+06
# ...             ...                ...   ...           ...
# 5026216         ZWE  SP.URB.TOTL.IN.ZS  2010  3.319600e+01
# 5026217         ZWE        SP.URB.GROW  2010  1.279630e+00
# 5026218         ZWE     DT.DOD.DIMF.CD  2010  5.287290e+08
# 5026219         ZWE     SN.ITK.VITA.ZS  2010  4.930002e+01
# 5026220         ZWE  SH.DYN.AIDS.FE.ZS  2010  5.898546e+01
#
# [5026221 rows x 4 columns]

# %%
dfcountry = di['CountryCode'].str.contains(country)

# %%
dfcountry
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 5026216    False
# 5026217    False
# 5026218    False
# 5026219    False
# 5026220    False
# Name: CountryCode, Length: 5026221, dtype: bool

# %%
dfcountry = di[di['CountryCode'].str.contains(country)]

# %%
dfcountry
# Out:
#         CountryCode         IndicatorCode  Year         Value
# 15484           MNG           SP.ADO.TFRT  1960  7.750180e+01
# 15485           MNG           SP.POP.DPND  1960  7.189306e+01
# 15486           MNG        SP.POP.DPND.OL  1960  8.298598e+00
# 15487           MNG        SP.POP.DPND.YG  1960  6.359446e+01
# 15488           MNG        MS.MIL.MPRT.KD  1960  1.000000e+07
# ...             ...                   ...   ...           ...
# 4963017         MNG     SL.EMP.WORK.MA.ZS  2010  3.850000e+01
# 4963018         MNG     SE.ADT.1524.LT.ZS  2010  9.846024e+01
# 4963019         MNG  SE.ADT.1524.LT.FE.ZS  2010  9.890874e+01
# 4963020         MNG  SE.ADT.1524.LT.FM.ZS  2010  1.009048e+00
# 4963021         MNG  SE.ADT.1524.LT.MA.ZS  2010  9.802181e+01
#
# [20389 rows x 4 columns]

# %%
di=0

# %% [markdown]
# borramos di porque ocupa mucho

# %% [markdown]
# Y ya estaria el reader
